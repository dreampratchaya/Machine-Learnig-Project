# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.datasets import load_boston

# %%
dataset = load_boston()

# %%
X = dataset.data
y = dataset.target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
ann = tf.keras.models.Sequential()
ann.add(tf.keras.layers.Dense(units = 80, activation = 'relu'))
ann.add(tf.keras.layers.Dense(units = 80, activation = 'relu'))
ann.add(tf.keras.layers.Dense(units = 1))
ann.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
ann.fit(X_train, y_train, batch_size = 20, epochs = 200, validation_data = (X_test, y_test))
# Out:
# Epoch 1/200
# 21/21 [==============================] - 1s 6ms/step - loss: 547.4567 - val_loss: 412.2577
# Epoch 2/200
# 21/21 [==============================] - 0s 3ms/step - loss: 404.6696 - val_loss: 263.5417
# Epoch 3/200
# 21/21 [==============================] - 0s 3ms/step - loss: 209.0408 - val_loss: 125.8183
# Epoch 4/200
# 21/21 [==============================] - 0s 3ms/step - loss: 91.9936 - val_loss: 78.2621
# Epoch 5/200
# 21/21 [==============================] - 0s 3ms/step - loss: 56.2742 - val_loss: 51.5905
# Epoch 6/200
# 21/21 [==============================] - 0s 3ms/step - loss: 37.8701 - val_loss: 37.8604
# Epoch 7/200
# 21/21 [==============================] - 0s 3ms/step - loss: 30.8763 - val_loss: 32.3364
# Epoch 8/200
# 21/21 [==============================] - 0s 3ms/step - loss: 27.1206 - val_loss: 28.9944
# Epoch 9/200
# 21/21 [==============================] - 0s 3ms/step - loss: 24.8188 - val_loss: 26.4471
# Epoch 10/200
# ...

# %%
y_pred = ann.predict(X_test)
data = {'Predict': y_pred.flatten(), 'Actual': y_test}
pd.DataFrame(data)
# Out:
#        Predict  Actual
# 0    23.966818    10.4
# 1    24.422749    22.1
# 2    24.376188    22.0
# 3    17.909426    14.5
# 4    18.179590    13.8
# ..         ...     ...
# 97   10.055010    12.8
# 98   34.691174    31.5
# 99   27.381008    23.3
# 100  27.112473    24.5
# 101  31.748428    33.0
#
# [102 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.8079095629828135
